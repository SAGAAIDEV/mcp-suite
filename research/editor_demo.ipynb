# %%
import assemblyai as aai
from config.env import AssemblyAI

# The API key will be loaded from your .env file through the config
api_key = AssemblyAI().API_KEY

# Initialize the client with your API key
aai.settings.api_key = api_key

# Example: Transcribe an audio file
transcriber = aai.Transcriber()
transcript = transcriber.transcribe(
    "/Users/andrew/Movies/Documentation/2025-03-11 20-19-08.mov"
)

# %% [markdown]
# ffmpeg -ss 64.928 -i "/Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov" -to 4.892 -c:v libx264 -c:a aac "/Users/andrew/Movies/Documentation/clip_vibe_segment_fixed.mov"

# %%
from langchain_anthropic import ChatAnthropic
from config.env import LLM_API_KEYS

model = ChatAnthropic(
    model="claude-3-7-sonnet-latest",
    anthropic_api_key=LLM_API_KEYS.ANTHROPIC_API_KEY,
    temperature=0.7,
)

from pydantic import BaseModel, Field


class Classifier(BaseModel):
    relevant: bool = Field(
        default=False,
        description="Is this informative conent. You want to return false for information that doesnt explain anything. Look to cut stutters or anything that lacks cohesiveness. This is audio of a video tutorial. Make sure you keep the into paragraph.",
    )
    reasoning: str = Field(
        default="", description="Your reasoning of why this text should be cut"
    )

prompts = [
    f"You are an educator and video tutorial expert. You are given a paragraph of text and you need to determine if it makes the cut. {p.text}"
    for p in transcript.get_paragraphs()
]

results = await model.with_structured_output(Classifier).abatch(prompts)

# %%
# Out:
# 2025-03-05 15:17:13,080 - INFO - HTTP Request: GET https://api.assemblyai.com/v2/transcript/742a5fa5-1d9d-4bb5-915c-0db603ea080b/paragraphs "HTTP/1.1 200 OK"

# %%
# Out:
# 2025-03-05 15:17:22,914 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:22,915 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:22,935 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:22,936 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:22,986 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:22,987 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:22,997 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:22,999 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:23,087 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,089 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:23,099 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,100 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:23,112 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,114 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:23,129 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,130 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:23,146 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,147 - INFO - Retrying request to /v1/messages in 3.000000 seconds
# 2025-03-05 15:17:23,214 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,215 - INFO - Retrying request to /v1/messages in 2.000000 seconds
# 2025-03-05 15:17:23,225 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-03-05 15:17:23,229 - INFO - Retrying request to /v1/messages in 2.000000 seconds
# 2025-03-05 15:17:24,778 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,058 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,078 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,252 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,405 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,464 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,481 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,578 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,614 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,628 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,653 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,655 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,656 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,680 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,696 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,702 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,709 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,753 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,783 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,814 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,882 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,885 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,895 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,906 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:25,931 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,012 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,035 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,045 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,134 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,146 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,175 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,221 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,243 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,382 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,554 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:26,571 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,159 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,190 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,730 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,771 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,885 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,912 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,915 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:28,919 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:29,037 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:29,428 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-03-05 15:17:29,647 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"

# %%
filters[0] = True

# %%
# Out:
# 2025-03-05 15:18:04,748 - INFO - HTTP Request: GET https://api.assemblyai.com/v2/transcript/742a5fa5-1d9d-4bb5-915c-0db603ea080b/paragraphs "HTTP/1.1 200 OK"

# %%
filtered_list
# Out:
# [Paragraph(text="Okay, so I am going to show you guys how I continue to use cursor and development. And so I have this vision, system architecture and technical requirements and user stories, this documentation that I've built up for this project. And I really want to push. I've seen this idea around vibe coding floating through, and I think that's stupid and ridiculous. You should not do that.", start=1040, end=32670, confidence=0.83302, speaker=None, channel=None, words=[Word(text='Okay,', start=1040, end=1664, confidence=0.83302, speaker=None, channel=None), Word(text='so', start=1752, end=2184, confidence=0.99473, speaker=None, channel=None), Word(text='I', start=2272, end=2472, confidence=0.99956, speaker=None, channel=None), Word(text='am', start=2496, end=2680, confidence=0.53552, speaker=None, channel=None), Word(text='going', start=2720, end=2872, confidence=0.86627, speaker=None, channel=None), Word(text='to', start=2896, end=2984, confidence=0.99922, speaker=None, channel=None), Word(text='show', start=2992, end=3160, confidence=0.99992, speaker=None, channel=None), Word(text='you', start=3200, end=3352, confidence=0.99988, speaker=None, channel=None), Word(text='guys', start=3376, end=4008, confidence=0.99797, speaker=None, channel=None), Word(text='how', start=4184, end=4568, confidence=0.99983, speaker=None, channel=None), Word(text='I', start=4624, end=4840, confidence=0.99981, speaker=None, channel=None), Word(text='continue', start=4880, end=5176, confidence=0.99966, speaker=None, channel=None), Word(text='to', start=5248, end=5432, confidence=0.99975, speaker=None, channel=None), Word(text='use', start=5456, end=5736, confidence=0.99976, speaker=None, channel=None), Word(text='cursor', start=5808, end=6296, confidence=0.62134, speaker=None, channel=None), Word(text='and', start=6328, end=6472, confidence=0.49892, speaker=None, channel=None), Word(text='development.', start=6496, end=7060, confidence=0.99963, speaker=None, channel=None), Word(text='And', start=7840, end=8392, confidence=0.95774, speaker=None, channel=None), Word(text='so', start=8496, end=9140, confidence=0.99563, speaker=None, channel=None), Word(text='I', start=9440, end=9800, confidence=0.99961, speaker=None, channel=None), Word(text='have', start=9840, end=10280, confidence=0.9999, speaker=None, channel=None), Word(text='this', start=10400, end=10920, confidence=0.99934, speaker=None, channel=None), Word(text='vision,', start=11040, end=11512, confidence=0.99746, speaker=None, channel=None), Word(text='system', start=11576, end=11848, confidence=0.99983, speaker=None, channel=None), Word(text='architecture', start=11904, end=12456, confidence=0.99971, speaker=None, channel=None), Word(text='and', start=12488, end=12968, confidence=0.99535, speaker=None, channel=None), Word(text='technical', start=13104, end=13672, confidence=0.99972, speaker=None, channel=None), Word(text='requirements', start=13736, end=14264, confidence=0.99934, speaker=None, channel=None), Word(text='and', start=14312, end=14472, confidence=0.95063, speaker=None, channel=None), Word(text='user', start=14496, end=14776, confidence=0.9998, speaker=None, channel=None), Word(text='stories,', start=14808, end=15288, confidence=0.99897, speaker=None, channel=None), Word(text='this', start=15384, end=15688, confidence=0.99919, speaker=None, channel=None), Word(text='documentation', start=15744, end=16376, confidence=0.96899, speaker=None, channel=None), Word(text='that', start=16408, end=16552, confidence=0.99847, speaker=None, channel=None), Word(text="I've", start=16576, end=16728, confidence=0.98173, speaker=None, channel=None), Word(text='built', start=16744, end=16936, confidence=0.99972, speaker=None, channel=None), Word(text='up', start=16968, end=17112, confidence=0.99971, speaker=None, channel=None), Word(text='for', start=17136, end=17272, confidence=0.99981, speaker=None, channel=None), Word(text='this', start=17296, end=17480, confidence=0.99969, speaker=None, chan ...
#  Paragraph(text="Engineering is a. It's a serious profession and it's a serious job. And it is a skill that takes a long time to master. I've been very lucky. I've been working with engineers that have 30 years experience and they're teaching me how to do this stuff.", start=33770, end=48146, confidence=0.99547, speaker=None, channel=None, words=[Word(text='Engineering', start=33770, end=34402, confidence=0.99547, speaker=None, channel=None), Word(text='is', start=34466, end=34642, confidence=0.9381, speaker=None, channel=None), Word(text='a.', start=34666, end=34898, confidence=0.82348, speaker=None, channel=None), Word(text="It's", start=34954, end=35186, confidence=0.94364, speaker=None, channel=None), Word(text='a', start=35218, end=35314, confidence=0.99899, speaker=None, channel=None), Word(text='serious', start=35322, end=35634, confidence=0.99934, speaker=None, channel=None), Word(text='profession', start=35682, end=36146, confidence=0.99973, speaker=None, channel=None), Word(text='and', start=36178, end=36322, confidence=0.99789, speaker=None, channel=None), Word(text="it's", start=36346, end=36498, confidence=0.99714, speaker=None, channel=None), Word(text='a', start=36514, end=36642, confidence=0.99886, speaker=None, channel=None), Word(text='serious', start=36666, end=37362, confidence=0.99972, speaker=None, channel=None), Word(text='job.', start=37506, end=38146, confidence=0.99939, speaker=None, channel=None), Word(text='And', start=38298, end=38562, confidence=0.99444, speaker=None, channel=None), Word(text='it', start=38586, end=38722, confidence=0.9996, speaker=None, channel=None), Word(text='is', start=38746, end=38930, confidence=0.99866, speaker=None, channel=None), Word(text='a', start=38970, end=39074, confidence=0.99904, speaker=None, channel=None), Word(text='skill', start=39082, end=39314, confidence=0.76244, speaker=None, channel=None), Word(text='that', start=39362, end=39522, confidence=0.99885, speaker=None, channel=None), Word(text='takes', start=39546, end=39826, confidence=0.99905, speaker=None, channel=None), Word(text='a', start=39858, end=40194, confidence=0.99803, speaker=None, channel=None), Word(text='long', start=40282, end=40578, confidence=0.99989, speaker=None, channel=None), Word(text='time', start=40634, end=40802, confidence=0.9993, speaker=None, channel=None), Word(text='to', start=40826, end=40962, confidence=0.99933, speaker=None, channel=None), Word(text='master.', start=40986, end=41634, confidence=0.99932, speaker=None, channel=None), Word(text="I've", start=41762, end=42018, confidence=0.99685, speaker=None, channel=None), Word(text='been', start=42034, end=42162, confidence=0.99971, speaker=None, channel=None), Word(text='very', start=42186, end=42370, confidence=0.99906, speaker=None, channel=None), Word(text='lucky.', start=42410, end=42754, confidence=0.99889, speaker=None, channel=None), Word(text="I've", start=42802, end=43298, confidence=0.98044, speaker=None, channel=None), Word(text='been', start=43394, end=43650, confidence=0.99941, speaker=None, channel=None), Word(text='working', start=43690, end=43938, confidence=0.99989, speaker=None, channel=None), Word(text='with', start=43994, end=44258, confidence=0.99968, speaker=None, channel=None), Word(text='engineers', start=44314, end=44754, confidence=0.99892, speaker=None, channel=None), Word(text='that', start=44802, end=44962, confidence=0.99523, speaker=None, channel=None), Word(text='have', start=44986, end=45170, confidence=0.9993, speaker=None, channel=None), Word(text='30', start=45210, end=45410, confidence=0.99951, speaker=None, channel=None), Word(text='years', start=45450, end=45698, confidence=0.9989, speaker=None, channel=None), Word(text='experience', start=45754, end=46306, confidence=0.99991, speaker=None, channel=None), Word(text='and', start=46458, end=46722, confidence=0.99724, speaker=None, channel=None), Word(text="they're", start=46746, end=46946, confidence=0.96346, speaker=None, channel=None), ...
#  Paragraph(text='And when you use these steps, you really start to fly. So. So this vibe coding where you just sit down and give it something vague and be like, make this and keep going. You are being sold snake oil. You will not be able to get something production ready if you do not follow these steps.', start=48178, end=64816, confidence=0.97322, speaker=None, channel=None, words=[Word(text='And', start=48178, end=48370, confidence=0.97322, speaker=None, channel=None), Word(text='when', start=48410, end=48562, confidence=0.99899, speaker=None, channel=None), Word(text='you', start=48586, end=48770, confidence=0.99967, speaker=None, channel=None), Word(text='use', start=48810, end=48962, confidence=0.9997, speaker=None, channel=None), Word(text='these', start=48986, end=49170, confidence=0.99745, speaker=None, channel=None), Word(text='steps,', start=49210, end=49698, confidence=0.62219, speaker=None, channel=None), Word(text='you', start=49794, end=50098, confidence=0.99977, speaker=None, channel=None), Word(text='really', start=50154, end=50370, confidence=0.99945, speaker=None, channel=None), Word(text='start', start=50410, end=50610, confidence=0.99941, speaker=None, channel=None), Word(text='to', start=50650, end=50802, confidence=0.99954, speaker=None, channel=None), Word(text='fly.', start=50826, end=51170, confidence=0.62192, speaker=None, channel=None), Word(text='So.', start=51250, end=51460, confidence=0.90365, speaker=None, channel=None), Word(text='So', start=51490, end=51584, confidence=0.8517, speaker=None, channel=None), Word(text='this', start=51592, end=51808, confidence=0.99003, speaker=None, channel=None), Word(text='vibe', start=51864, end=52144, confidence=0.99458, speaker=None, channel=None), Word(text='coding', start=52192, end=52496, confidence=0.89395, speaker=None, channel=None), Word(text='where', start=52528, end=52672, confidence=0.99816, speaker=None, channel=None), Word(text='you', start=52696, end=52832, confidence=0.99967, speaker=None, channel=None), Word(text='just', start=52856, end=52992, confidence=0.99949, speaker=None, channel=None), Word(text='sit', start=53016, end=53200, confidence=0.99971, speaker=None, channel=None), Word(text='down', start=53240, end=53392, confidence=0.99964, speaker=None, channel=None), Word(text='and', start=53416, end=53840, confidence=0.5311, speaker=None, channel=None), Word(text='give', start=53960, end=54192, confidence=0.99968, speaker=None, channel=None), Word(text='it', start=54216, end=54448, confidence=0.9994, speaker=None, channel=None), Word(text='something', start=54504, end=54816, confidence=0.99942, speaker=None, channel=None), Word(text='vague', start=54888, end=55184, confidence=0.99885, speaker=None, channel=None), Word(text='and', start=55232, end=55344, confidence=0.99893, speaker=None, channel=None), Word(text='be', start=55352, end=55472, confidence=0.9955, speaker=None, channel=None), Word(text='like,', start=55496, end=55680, confidence=0.99406, speaker=None, channel=None), Word(text='make', start=55720, end=55920, confidence=0.99939, speaker=None, channel=None), Word(text='this', start=55960, end=56112, confidence=0.9997, speaker=None, channel=None), Word(text='and', start=56136, end=56272, confidence=0.99863, speaker=None, channel=None), Word(text='keep', start=56296, end=56480, confidence=0.99989, speaker=None, channel=None), Word(text='going.', start=56520, end=57008, confidence=0.99952, speaker=None, channel=None), Word(text='You', start=57144, end=57392, confidence=0.99978, speaker=None, channel=None), Word(text='are', start=57416, end=57600, confidence=0.74151, speaker=None, channel=None), Word(text='being', start=57640, end=57936, confidence=0.99992, speaker=None, channel=None), Word(text='sold', start=58008, end=58352, confidence=0.99893, speaker=None, channel=None), Word(text='snake', start=58416, end=58736, confidence=0.99974, speaker=None, channel=None), Word(text='oil.', start=58768, end=59104, confidence=0.99995, speaker= ...
#  Paragraph(text="So it's picking up from my user stories, my vision, my technical requirements and system and it's building me this document. So from this I have this first Sprint here right now.", start=220644, end=238290, confidence=0.98894, speaker=None, channel=None, words=[Word(text='So', start=220644, end=220764, confidence=0.98894, speaker=None, channel=None), Word(text="it's", start=220772, end=220908, confidence=0.9985, speaker=None, channel=None), Word(text='picking', start=220924, end=221196, confidence=0.99983, speaker=None, channel=None), Word(text='up', start=221228, end=221372, confidence=0.99987, speaker=None, channel=None), Word(text='from', start=221396, end=221532, confidence=0.86627, speaker=None, channel=None), Word(text='my', start=221556, end=221692, confidence=0.99938, speaker=None, channel=None), Word(text='user', start=221716, end=222076, confidence=0.99974, speaker=None, channel=None), Word(text='stories,', start=222108, end=222492, confidence=0.42034, speaker=None, channel=None), Word(text='my', start=222556, end=222732, confidence=0.99973, speaker=None, channel=None), Word(text='vision,', start=222756, end=223084, confidence=0.99948, speaker=None, channel=None), Word(text='my', start=223132, end=223292, confidence=0.999, speaker=None, channel=None), Word(text='technical', start=223316, end=223772, confidence=0.99865, speaker=None, channel=None), Word(text='requirements', start=223836, end=224588, confidence=0.99933, speaker=None, channel=None), Word(text='and', start=224684, end=224940, confidence=0.99581, speaker=None, channel=None), Word(text='system', start=224980, end=225228, confidence=0.99881, speaker=None, channel=None), Word(text='and', start=225284, end=225404, confidence=0.99707, speaker=None, channel=None), Word(text="it's", start=225412, end=225596, confidence=0.99736, speaker=None, channel=None), Word(text='building', start=225628, end=225868, confidence=0.99896, speaker=None, channel=None), Word(text='me', start=225924, end=226092, confidence=0.99749, speaker=None, channel=None), Word(text='this', start=226116, end=226732, confidence=0.99954, speaker=None, channel=None), Word(text='document.', start=226916, end=227756, confidence=0.95645, speaker=None, channel=None), Word(text='So', start=227868, end=228520, confidence=0.9796, speaker=None, channel=None), Word(text='from', start=228980, end=229436, confidence=0.99951, speaker=None, channel=None), Word(text='this', start=229508, end=230120, confidence=0.99922, speaker=None, channel=None), Word(text='I', start=233140, end=233548, confidence=0.99906, speaker=None, channel=None), Word(text='have', start=233604, end=234060, confidence=0.99973, speaker=None, channel=None), Word(text='this', start=234180, end=234508, confidence=0.99979, speaker=None, channel=None), Word(text='first', start=234564, end=234828, confidence=0.99593, speaker=None, channel=None), Word(text='Sprint', start=234884, end=235324, confidence=0.65929, speaker=None, channel=None), Word(text='here', start=235372, end=235964, confidence=0.997, speaker=None, channel=None), Word(text='right', start=236132, end=236840, confidence=0.94565, speaker=None, channel=None), Word(text='now.', start=237550, end=238290, confidence=0.97018, speaker=None, channel=None)]),
#  Paragraph(text='The Sprint goal is for getting a base service class that has persistent capabilities to save in JIRA and automatic service registration. And this should be used by any service that in MCP tool server call will use.', start=277160, end=309060, confidence=0.98946, speaker=None, channel=None, words=[Word(text='The', start=277160, end=277520, confidence=0.98946, speaker=None, channel=None), Word(text='Sprint', start=277560, end=277904, confidence=0.59593, speaker=None, channel=None), Word(text='goal', start=277952, end=278592, confidence=0.99789, speaker=None, channel=None), Word(text='is', start=278736, end=279424, confidence=0.99874, speaker=None, channel=None), Word(text='for', start=279592, end=280300, confidence=0.99833, speaker=None, channel=None), Word(text='getting', start=281400, end=281760, confidence=0.99824, speaker=None, channel=None), Word(text='a', start=281800, end=281952, confidence=0.99886, speaker=None, channel=None), Word(text='base', start=281976, end=282592, confidence=0.72672, speaker=None, channel=None), Word(text='service', start=282736, end=283184, confidence=0.99943, speaker=None, channel=None), Word(text='class', start=283272, end=283664, confidence=0.99965, speaker=None, channel=None), Word(text='that', start=283752, end=284096, confidence=0.9994, speaker=None, channel=None), Word(text='has', start=284168, end=284780, confidence=0.99927, speaker=None, channel=None), Word(text='persistent', start=285560, end=286660, confidence=0.99716, speaker=None, channel=None), Word(text='capabilities', start=287720, end=288580, confidence=0.34531, speaker=None, channel=None), Word(text='to', start=289360, end=289768, confidence=0.98486, speaker=None, channel=None), Word(text='save', start=289824, end=290152, confidence=0.99799, speaker=None, channel=None), Word(text='in', start=290216, end=290820, confidence=0.9978, speaker=None, channel=None), Word(text='JIRA', start=291520, end=292408, confidence=0.58338, speaker=None, channel=None), Word(text='and', start=292504, end=292856, confidence=0.91012, speaker=None, channel=None), Word(text='automatic', start=292928, end=293512, confidence=0.99962, speaker=None, channel=None), Word(text='service', start=293576, end=294088, confidence=0.99939, speaker=None, channel=None), Word(text='registration.', start=294224, end=295100, confidence=0.99933, speaker=None, channel=None), Word(text='And', start=296000, end=296740, confidence=0.9739, speaker=None, channel=None), Word(text='this', start=298720, end=299512, confidence=0.99972, speaker=None, channel=None), Word(text='should', start=299696, end=300136, confidence=0.99998, speaker=None, channel=None), Word(text='be', start=300208, end=300824, confidence=0.99993, speaker=None, channel=None), Word(text='used', start=300992, end=301464, confidence=0.99986, speaker=None, channel=None), Word(text='by', start=301552, end=301896, confidence=0.99997, speaker=None, channel=None), Word(text='any', start=301968, end=302344, confidence=0.9999, speaker=None, channel=None), Word(text='service', start=302432, end=303060, confidence=0.99968, speaker=None, channel=None), Word(text='that', start=303600, end=304340, confidence=0.99962, speaker=None, channel=None), Word(text='in', start=304960, end=305320, confidence=0.53317, speaker=None, channel=None), Word(text='MCP', start=305360, end=306072, confidence=0.96165, speaker=None, channel=None), Word(text='tool', start=306136, end=306600, confidence=0.99245, speaker=None, channel=None), Word(text='server', start=306720, end=307496, confidence=0.97327, speaker=None, channel=None), Word(text='call', start=307608, end=308072, confidence=0.99486, speaker=None, channel=None), Word(text='will', start=308176, end=308440, confidence=0.99355, speaker=None, channel=None), Word(text='use.', start=308480, end=309060, confidence=0.99748, speaker=None, channel=None)]),
#  Paragraph(text="And this is. So what's very cool about this is that as you're working in this documentation and you're doing a user story and then you come to something you didn't think about while you're doing this documentation, these tools allow you to push those ideas back up into your documentation so you get a more refined plan. And so that's very helpful for grounding chat with context so it performs much better. And then you're going to learn, you know, what the model is good at, what it misses, and then you're going to learn, you know, what rules do you need to do you need to do. So going to review this and go over this.", start=921790, end=963730, confidence=0.81648, speaker=None, channel=None, words=[Word(text='And', start=921790, end=922486, confidence=0.81648, speaker=None, channel=None), Word(text='this', start=922638, end=922902, confidence=0.94309, speaker=None, channel=None), Word(text='is.', start=922926, end=923350, confidence=0.99422, speaker=None, channel=None), Word(text='So', start=923470, end=923702, confidence=0.97387, speaker=None, channel=None), Word(text="what's", start=923726, end=923958, confidence=0.99559, speaker=None, channel=None), Word(text='very', start=923974, end=924150, confidence=0.99623, speaker=None, channel=None), Word(text='cool', start=924190, end=924406, confidence=0.99981, speaker=None, channel=None), Word(text='about', start=924438, end=924630, confidence=0.99848, speaker=None, channel=None), Word(text='this', start=924670, end=924966, confidence=0.99957, speaker=None, channel=None), Word(text='is', start=925038, end=925318, confidence=0.99792, speaker=None, channel=None), Word(text='that', start=925374, end=925970, confidence=0.99694, speaker=None, channel=None), Word(text='as', start=927230, end=927590, confidence=0.9992, speaker=None, channel=None), Word(text="you're", start=927630, end=927798, confidence=0.99493, speaker=None, channel=None), Word(text='working', start=927814, end=928038, confidence=0.99983, speaker=None, channel=None), Word(text='in', start=928094, end=928214, confidence=0.997, speaker=None, channel=None), Word(text='this', start=928222, end=928390, confidence=0.99905, speaker=None, channel=None), Word(text='documentation', start=928430, end=929062, confidence=0.99813, speaker=None, channel=None), Word(text='and', start=929126, end=929302, confidence=0.89105, speaker=None, channel=None), Word(text="you're", start=929326, end=929478, confidence=0.99421, speaker=None, channel=None), Word(text='doing', start=929494, end=929670, confidence=0.99932, speaker=None, channel=None), Word(text='a', start=929710, end=929862, confidence=0.98898, speaker=None, channel=None), Word(text='user', start=929886, end=930118, confidence=0.99984, speaker=None, channel=None), Word(text='story', start=930134, end=930358, confidence=0.51526, speaker=None, channel=None), Word(text='and', start=930414, end=930582, confidence=0.97009, speaker=None, channel=None), Word(text='then', start=930606, end=930742, confidence=0.98725, speaker=None, channel=None), Word(text='you', start=930766, end=930902, confidence=0.99951, speaker=None, channel=None), Word(text='come', start=930926, end=931062, confidence=0.99988, speaker=None, channel=None), Word(text='to', start=931086, end=931222, confidence=0.99944, speaker=None, channel=None), Word(text='something', start=931246, end=931430, confidence=0.99972, speaker=None, channel=None), Word(text='you', start=931470, end=931622, confidence=0.99744, speaker=None, channel=None), Word(text="didn't", start=931646, end=931846, confidence=0.75328, speaker=None, channel=None), Word(text='think', start=931878, end=932022, confidence=0.99963, speaker=None, channel=None), Word(text='about', start=932046, end=932230, confidence=0.99923, speaker=None, channel=None), Word(text='while', start=932270, end=932422, confidence=0.99801, speaker=None, channel=None), Word(text="you're", start=932446, end=932646, confidence=0.94582, speaker=None, channel=None), Word(text='d ...
#  Paragraph(text="And so something I encountered is what I find is quite neat is for logging, I've never encountered struct log before. And that's what I find really fascinating about this technology is, you know, you're just working along and then it's like, oh, hey, use this. And then I can be like, explain struct log to me now. Just discovering this. This is actually, I need this for some of the things that I'm doing because I want Cursor to be able to read logs and then parse them.", start=1117770, end=1162500, confidence=0.96678, speaker=None, channel=None, words=[Word(text='And', start=1117770, end=1118130, confidence=0.96678, speaker=None, channel=None), Word(text='so', start=1118170, end=1118322, confidence=0.99883, speaker=None, channel=None), Word(text='something', start=1118346, end=1118578, confidence=0.99896, speaker=None, channel=None), Word(text='I', start=1118634, end=1118802, confidence=0.99917, speaker=None, channel=None), Word(text='encountered', start=1118826, end=1119522, confidence=0.93794, speaker=None, channel=None), Word(text='is', start=1119666, end=1120210, confidence=0.9794, speaker=None, channel=None), Word(text='what', start=1120330, end=1120562, confidence=0.9994, speaker=None, channel=None), Word(text='I', start=1120586, end=1120722, confidence=0.99925, speaker=None, channel=None), Word(text='find', start=1120746, end=1120930, confidence=0.99943, speaker=None, channel=None), Word(text='is', start=1120970, end=1121314, confidence=0.97773, speaker=None, channel=None), Word(text='quite', start=1121402, end=1121714, confidence=0.99986, speaker=None, channel=None), Word(text='neat', start=1121762, end=1122402, confidence=0.99836, speaker=None, channel=None), Word(text='is', start=1122546, end=1123230, confidence=0.99508, speaker=None, channel=None), Word(text='for', start=1125850, end=1126258, confidence=0.99679, speaker=None, channel=None), Word(text='logging,', start=1126314, end=1126802, confidence=0.90387, speaker=None, channel=None), Word(text="I've", start=1126866, end=1127106, confidence=0.99332, speaker=None, channel=None), Word(text='never', start=1127138, end=1127330, confidence=0.99984, speaker=None, channel=None), Word(text='encountered', start=1127370, end=1127714, confidence=0.86617, speaker=None, channel=None), Word(text='struct', start=1127762, end=1128114, confidence=0.93919, speaker=None, channel=None), Word(text='log', start=1128162, end=1128418, confidence=0.98142, speaker=None, channel=None), Word(text='before.', start=1128474, end=1128690, confidence=0.99996, speaker=None, channel=None), Word(text='And', start=1128730, end=1128882, confidence=0.98892, speaker=None, channel=None), Word(text="that's", start=1128906, end=1129058, confidence=0.99914, speaker=None, channel=None), Word(text='what', start=1129074, end=1129154, confidence=0.99908, speaker=None, channel=None), Word(text='I', start=1129162, end=1129282, confidence=0.99945, speaker=None, channel=None), Word(text='find', start=1129306, end=1129490, confidence=0.99923, speaker=None, channel=None), Word(text='really', start=1129530, end=1129826, confidence=0.99821, speaker=None, channel=None), Word(text='fascinating', start=1129898, end=1130386, confidence=0.79795, speaker=None, channel=None), Word(text='about', start=1130418, end=1130610, confidence=0.99948, speaker=None, channel=None), Word(text='this', start=1130650, end=1130850, confidence=0.99954, speaker=None, channel=None), Word(text='technology', start=1130890, end=1131330, confidence=0.99965, speaker=None, channel=None), Word(text='is,', start=1131450, end=1131922, confidence=0.98435, speaker=None, channel=None), Word(text='you', start=1132026, end=1132194, confidence=0.87992, speaker=None, channel=None), Word(text='know,', start=1132202, end=1132322, confidence=0.99922, speaker=None, channel=None), Word(text="you're", start=1132346, end=1132498, confidence=0.99783, speaker=None, channel=None), Word(text='just', start=1132514, end=1132690, confidence=0.99952, speaker= ...
#  Paragraph(text="It all right. So, you know, and I. So. But what's really cool is I was able to assess some technologies and narrow that question down, right, by asking chat coming to something that I don't know, stopping, asking questions, learning, that's where this technology is really powerful. And so this is what I really want to caution people against.", start=1190980, end=1247292, confidence=0.70945, speaker=None, channel=None, words=[Word(text='It', start=1190980, end=1191720, confidence=0.70945, speaker=None, channel=None), Word(text='all', start=1221470, end=1221734, confidence=0.68277, speaker=None, channel=None), Word(text='right.', start=1221742, end=1222006, confidence=0.95234, speaker=None, channel=None), Word(text='So,', start=1222078, end=1222358, confidence=0.99326, speaker=None, channel=None), Word(text='you', start=1222414, end=1222582, confidence=0.98726, speaker=None, channel=None), Word(text='know,', start=1222606, end=1222742, confidence=0.99922, speaker=None, channel=None), Word(text='and', start=1222766, end=1222902, confidence=0.92513, speaker=None, channel=None), Word(text='I.', start=1222926, end=1223350, confidence=0.93944, speaker=None, channel=None), Word(text='So.', start=1223470, end=1224038, confidence=0.98288, speaker=None, channel=None), Word(text='But', start=1224174, end=1224470, confidence=0.51778, speaker=None, channel=None), Word(text="what's", start=1224510, end=1224758, confidence=0.99771, speaker=None, channel=None), Word(text='really', start=1224774, end=1224902, confidence=0.99978, speaker=None, channel=None), Word(text='cool', start=1224926, end=1225078, confidence=0.99975, speaker=None, channel=None), Word(text='is', start=1225094, end=1225222, confidence=0.97904, speaker=None, channel=None), Word(text='I', start=1225246, end=1225334, confidence=0.99841, speaker=None, channel=None), Word(text='was', start=1225342, end=1225510, confidence=0.99912, speaker=None, channel=None), Word(text='able', start=1225550, end=1225702, confidence=0.99986, speaker=None, channel=None), Word(text='to', start=1225726, end=1226290, confidence=0.99913, speaker=None, channel=None), Word(text='assess', start=1229630, end=1230134, confidence=0.98724, speaker=None, channel=None), Word(text='some', start=1230182, end=1230342, confidence=0.99855, speaker=None, channel=None), Word(text='technologies', start=1230366, end=1231030, confidence=0.98082, speaker=None, channel=None), Word(text='and', start=1231110, end=1231302, confidence=0.99018, speaker=None, channel=None), Word(text='narrow', start=1231326, end=1231606, confidence=0.99882, speaker=None, channel=None), Word(text='that', start=1231638, end=1231782, confidence=0.99931, speaker=None, channel=None), Word(text='question', start=1231806, end=1232086, confidence=0.99984, speaker=None, channel=None), Word(text='down,', start=1232158, end=1232582, confidence=0.99906, speaker=None, channel=None), Word(text='right,', start=1232686, end=1232950, confidence=0.98316, speaker=None, channel=None), Word(text='by', start=1232990, end=1233190, confidence=0.99904, speaker=None, channel=None), Word(text='asking', start=1233230, end=1233542, confidence=0.65063, speaker=None, channel=None), Word(text='chat', start=1233606, end=1234262, confidence=0.99154, speaker=None, channel=None), Word(text='coming', start=1234406, end=1234758, confidence=0.99959, speaker=None, channel=None), Word(text='to', start=1234814, end=1234982, confidence=0.99971, speaker=None, channel=None), Word(text='something', start=1235006, end=1235334, confidence=0.99951, speaker=None, channel=None), Word(text='that', start=1235422, end=1235622, confidence=0.9991, speaker=None, channel=None), Word(text='I', start=1235646, end=1235782, confidence=0.99961, speaker=None, channel=None), Word(text="don't", start=1235806, end=1236006, confidence=0.99812, speaker=None, channel=None), Word(text='know,', start=1236038, end=1236422, confidence=0.99892, speaker=None, channel=None), Word(text='stopping,', start= ...
#  Paragraph(text='And so we want to use this technology not to get rich quick, but to build better quality and build a better world.', start=1273620, end=1284440, confidence=0.88682, speaker=None, channel=None, words=[Word(text='And', start=1273620, end=1273980, confidence=0.88682, speaker=None, channel=None), Word(text='so', start=1274020, end=1274172, confidence=0.99636, speaker=None, channel=None), Word(text='we', start=1274196, end=1274332, confidence=0.99929, speaker=None, channel=None), Word(text='want', start=1274356, end=1274492, confidence=0.95168, speaker=None, channel=None), Word(text='to', start=1274516, end=1274604, confidence=0.99838, speaker=None, channel=None), Word(text='use', start=1274612, end=1274732, confidence=0.99956, speaker=None, channel=None), Word(text='this', start=1274756, end=1274988, confidence=0.99788, speaker=None, channel=None), Word(text='technology', start=1275044, end=1275640, confidence=0.99939, speaker=None, channel=None), Word(text='not', start=1276100, end=1276412, confidence=0.99866, speaker=None, channel=None), Word(text='to', start=1276436, end=1276572, confidence=0.9981, speaker=None, channel=None), Word(text='get', start=1276596, end=1276780, confidence=0.99981, speaker=None, channel=None), Word(text='rich', start=1276820, end=1277132, confidence=0.99967, speaker=None, channel=None), Word(text='quick,', start=1277196, end=1277708, confidence=0.99996, speaker=None, channel=None), Word(text='but', start=1277844, end=1278140, confidence=0.99938, speaker=None, channel=None), Word(text='to', start=1278180, end=1278476, confidence=0.99881, speaker=None, channel=None), Word(text='build', start=1278548, end=1278924, confidence=0.99883, speaker=None, channel=None), Word(text='better', start=1279012, end=1279452, confidence=0.99823, speaker=None, channel=None), Word(text='quality', start=1279556, end=1280400, confidence=0.99932, speaker=None, channel=None), Word(text='and', start=1282500, end=1282956, confidence=0.89317, speaker=None, channel=None), Word(text='build', start=1283028, end=1283308, confidence=0.99688, speaker=None, channel=None), Word(text='a', start=1283364, end=1283484, confidence=0.99874, speaker=None, channel=None), Word(text='better', start=1283492, end=1283756, confidence=0.99986, speaker=None, channel=None), Word(text='world.', start=1283828, end=1284440, confidence=0.99989, speaker=None, channel=None)])]

# %%
def create_ffmpeg_command(paragraph, input_file, output_dir=None, output_filename=None):
    """
    Create an ffmpeg command to extract a segment from a video based on paragraph timestamps.

    Args:
        paragraph: An object with text, start, and end attributes (timestamps in milliseconds)
        input_file: Path to the input video file
        output_dir: Directory for the output file (defaults to same as input)
        output_filename: Custom filename for the output (defaults to auto-generated from text)

    Returns:
        str: The complete ffmpeg command
    """
    from pathlib import Path
    import re

    # Convert milliseconds to seconds
    start_sec = paragraph.start / 1000
    duration_sec = (paragraph.end - paragraph.start) / 1000

    # Create a filename from the text if not provided
    if output_filename is None:
        # Take first 5 words of text and clean it for a filename
        words = paragraph.text.split()[:5]
        clean_text = "_".join(words)
        # Remove special characters
        clean_text = re.sub(r"[^\w\s]", "", clean_text)
        clean_text = clean_text.replace(" ", "_").lower()
        output_filename = f"clip_{clean_text}.mov"

    # Set output directory
    if output_dir is None:
        output_dir = str(Path(input_file).parent)

    # Construct full output path
    output_path = str(Path(output_dir) / output_filename)

    # Create the ffmpeg command
    command = (
        f'ffmpeg -ss {start_sec:.3f} -i "{input_file}" -to {duration_sec:.3f} '
        f'-c:v libx264 -c:a aac "{output_path}"'
    )

    return command

# %%
def create_commands_for_paragraphs(paragraphs, input_file, output_dir=None):
    """
    Create ffmpeg commands for a list of paragraphs.

    Args:
        paragraphs: List of paragraph objects with text, start, and end attributes
        input_file: Path to the input video file
        output_dir: Directory for output files

    Returns:
        list: List of ffmpeg commands
    """
    commands = []
    for i, paragraph in enumerate(paragraphs):
        # Create a numbered filename
        output_filename = f"clip_{i+1:03d}.mov"
        command = create_ffmpeg_command(
            paragraph,
            input_file,
            output_dir=output_dir,
            output_filename=output_filename,
        )
        commands.append(command)
    return commands

# %%
import os
import subprocess
import concurrent.futures
from pathlib import Path
import tempfile
import re

# %%
def process_clip(paragraph, input_file, output_dir, clip_index):
    """Process a single clip in parallel"""
    output_filename = f"clip_{clip_index:03d}.mov"
    command, output_path = create_ffmpeg_command(
        paragraph, input_file, output_dir, output_filename
    )

    try:
        subprocess.run(command, check=True, capture_output=True)
        return {
            "success": True,
            "output_path": output_path,
            "index": clip_index,
            "error": None,
        }
    except subprocess.CalledProcessError as e:
        return {
            "success": False,
            "output_path": None,
            "index": clip_index,
            "error": str(e),
        }


def create_concat_file(clip_paths, concat_file_path):
    """Create a concat file for ffmpeg"""
    with open(concat_file_path, "w") as f:
        for path in clip_paths:
            f.write(f"file '{path}'\n")


def concatenate_clips(clip_paths, output_file):
    """Concatenate clips into a final video"""
    # Create a temporary concat file
    with tempfile.NamedTemporaryFile(mode="w", suffix=".txt", delete=False) as temp:
        concat_file = temp.name
        create_concat_file(clip_paths, concat_file)

    # Run ffmpeg to concatenate the clips
    command = [
        "ffmpeg",
        "-f",
        "concat",
        "-safe",
        "0",
        "-i",
        concat_file,
        "-c",
        "copy",
        output_file,
    ]

    try:
        subprocess.run(command, check=True)
        os.unlink(concat_file)  # Delete the temporary file
        return True
    except subprocess.CalledProcessError as e:
        print(f"Error concatenating clips: {e}")
        return False

from loguru import logger
def process_paragraphs(
    paragraphs, input_file, output_dir, final_output_file, max_workers=4
):
    """
    Process a list of paragraphs, then concatenate them.

    Args:
        paragraphs: List of paragraph objects with text, start, and end attributes
        input_file: Path to the input video file
        output_dir: Directory for output files
        final_output_file: Path for the final concatenated video
        max_workers: Maximum number of parallel threads (default: 4)

    Returns:
        bool: Success status
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Process clips in parallel using ThreadPoolExecutor instead of ProcessPoolExecutor
    results = []

    # Option 1: Process sequentially if having issues with parallel processing
    if max_workers == 1:
        logger.info("Processing clips sequentially")
        for i, paragraph in enumerate(paragraphs):
            result = process_clip(paragraph, input_file, output_dir, i + 1)
            results.append(result)
    else:
        # Option 2: Process in parallel with ThreadPoolExecutor
        logger.info(f"Processing clips in parallel with {max_workers} workers")
        with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
            futures = []
            for i, paragraph in enumerate(paragraphs):
                future = executor.submit(
                    process_clip, paragraph, input_file, output_dir, i + 1
                )
                futures.append(future)

            # Collect results as they complete
            for future in concurrent.futures.as_completed(futures):
                try:
                    result = future.result()
                    results.append(result)
                except Exception as e:
                    logger.error(f"Error in thread: {e}")
                    results.append(
                        {
                            "success": False,
                            "output_path": None,
                            "index": -1,
                            "error": f"Thread error: {e}",
                        }
                    )

    # Check if all clips were processed successfully
    successful_results = [r for r in results if r["success"]]
    failed_results = [r for r in results if not r["success"]]

    logger.info(f"Processed {len(successful_results)} clips successfully")
    if failed_results:
        logger.warning(f"Failed to process {len(failed_results)} clips")
        for fail in failed_results:
            logger.warning(f"  Clip {fail['index']}: {fail['error']}")

    if not successful_results:
        logger.error("No clips were processed successfully. Aborting concatenation.")
        return False

    # Sort results by index to maintain order
    successful_results.sort(key=lambda x: x["index"])
    clip_paths = [result["output_path"] for result in successful_results]

    # Concatenate all clips
    logger.info("Concatenating clips...")
    success = concatenate_clips(clip_paths, final_output_file)

    if success:
        logger.info(f"Final video created at: {final_output_file}")

    return success

# %%
import os
import subprocess
import concurrent.futures
from pathlib import Path
import tempfile
import re
import logging
from dataclasses import dataclass
from typing import Optional, List

# Set up logging
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)


@dataclass
class Paragraph:
    """Class to represent a paragraph with timestamps"""

    text: str
    start: int
    end: int


def create_ffmpeg_command(paragraph, input_file, output_dir, output_filename=None):
    """
    Create an ffmpeg command to extract a segment from a video based on paragraph timestamps.

    Args:
        paragraph: An object with text, start, and end attributes (timestamps in milliseconds)
        input_file: Path to the input video file
        output_dir: Directory for the output file
        output_filename: Custom filename for the output (defaults to auto-generated from text)

    Returns:
        tuple: The complete ffmpeg command and output path
    """
    # Convert milliseconds to seconds
    start_sec = paragraph.start / 1000
    duration_sec = (paragraph.end - paragraph.start) / 1000

    # Create a filename from the text if not provided
    if output_filename is None:
        # Take first 5 words of text and clean it for a filename
        words = paragraph.text.split()[:5]
        clean_text = "_".join(words)
        # Remove special characters
        clean_text = re.sub(r"[^\w\s]", "", clean_text)
        clean_text = clean_text.replace(" ", "_").lower()
        output_filename = f"clip_{clean_text}.mov"

    # Construct full output path
    output_path = str(Path(output_dir) / output_filename)

    # Create the ffmpeg command
    command = [
        "ffmpeg",
        "-ss",
        f"{start_sec:.3f}",
        "-i",
        input_file,
        "-to",
        f"{duration_sec:.3f}",
        "-c:v",
        "libx264",
        "-c:a",
        "aac",
        "-y",
        output_path,  # Add -y to overwrite existing files
    ]

    return command, output_path


def process_clip(args):
    """
    Process a single clip - takes a single argument to avoid unpacking issues

    Args:
        args: A tuple containing (paragraph, input_file, output_dir, clip_index)

    Returns:
        dict: Result information
    """
    paragraph, input_file, output_dir, clip_index = args

    output_filename = f"clip_{clip_index:03d}.mov"
    command, output_path = create_ffmpeg_command(
        paragraph, input_file, output_dir, output_filename
    )

    logger.info(f"Processing clip {clip_index}: {' '.join(command)}")

    try:
        # Run with a timeout to prevent hanging processes
        result = subprocess.run(
            command,
            check=True,
            capture_output=True,
            text=True,
            timeout=300,  # 5 minute timeout
        )
        logger.info(f"Successfully processed clip {clip_index}")
        return {
            "success": True,
            "output_path": output_path,
            "index": clip_index,
            "error": None,
        }
    except subprocess.CalledProcessError as e:
        logger.error(f"Error processing clip {clip_index}: {e}")
        logger.error(f"STDERR: {e.stderr}")
        return {
            "success": False,
            "output_path": None,
            "index": clip_index,
            "error": f"Process error: {e}",
        }
    except subprocess.TimeoutExpired as e:
        logger.error(f"Timeout processing clip {clip_index}: {e}")
        return {
            "success": False,
            "output_path": None,
            "index": clip_index,
            "error": f"Timeout: {e}",
        }
    except Exception as e:
        logger.error(f"Unexpected error processing clip {clip_index}: {e}")
        return {
            "success": False,
            "output_path": None,
            "index": clip_index,
            "error": f"Unexpected error: {e}",
        }


def create_concat_file(clip_paths, concat_file_path):
    """Create a concat file for ffmpeg"""
    with open(concat_file_path, "w") as f:
        for path in clip_paths:
            # Use absolute paths and escape single quotes
            abs_path = os.path.abspath(path).replace("'", "'\\''")
            f.write(f"file '{abs_path}'\n")


def concatenate_clips(clip_paths, output_file):
    """Concatenate clips into a final video"""
    if not clip_paths:
        logger.error("No clips to concatenate")
        return False

    # Create a temporary concat file
    with tempfile.NamedTemporaryFile(mode="w", suffix=".txt", delete=False) as temp:
        concat_file = temp.name
        create_concat_file(clip_paths, concat_file)

    logger.info(f"Created concat file at {concat_file}")

    # Run ffmpeg to concatenate the clips
    command = [
        "ffmpeg",
        "-f",
        "concat",
        "-safe",
        "0",
        "-i",
        concat_file,
        "-c",
        "copy",
        "-y",
        output_file,
    ]

    logger.info(f"Running concat command: {' '.join(command)}")

    try:
        subprocess.run(command, check=True, capture_output=True, text=True)
        logger.info(f"Successfully concatenated clips to {output_file}")
        os.unlink(concat_file)  # Delete the temporary file
        return True
    except subprocess.CalledProcessError as e:
        logger.error(f"Error concatenating clips: {e}")
        logger.error(f"STDERR: {e.stderr}")
        return False
    except Exception as e:
        logger.error(f"Unexpected error during concatenation: {e}")
        return False


def process_paragraphs(
    paragraphs, input_file, output_dir, final_output_file, max_workers=4
):
    """
    Process a list of paragraphs, then concatenate them.

    Args:
        paragraphs: List of paragraph objects with text, start, and end attributes
        input_file: Path to the input video file
        output_dir: Directory for output files
        final_output_file: Path for the final concatenated video
        max_workers: Maximum number of parallel threads (default: 4)

    Returns:
        bool: Success status
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Process clips in parallel using ThreadPoolExecutor instead of ProcessPoolExecutor
    results = []

    # Option 1: Process sequentially if having issues with parallel processing
    if max_workers == 1:
        logger.info("Processing clips sequentially")
        for i, paragraph in enumerate(paragraphs):
            result = process_clip((paragraph, input_file, output_dir, i + 1))
            results.append(result)
    else:
        # Option 2: Process in parallel with ThreadPoolExecutor
        logger.info(f"Processing clips in parallel with {max_workers} workers")
        with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
            # Create a list of argument tuples to avoid unpacking issues
            tasks = [
                (paragraph, input_file, output_dir, i + 1)
                for i, paragraph in enumerate(paragraphs)
            ]

            # Map the process_clip function to the tasks
            for result in executor.map(process_clip, tasks):
                results.append(result)

    # Check if all clips were processed successfully
    successful_results = [r for r in results if r["success"]]
    failed_results = [r for r in results if not r["success"]]

    logger.info(f"Processed {len(successful_results)} clips successfully")
    if failed_results:
        logger.warning(f"Failed to process {len(failed_results)} clips")
        for fail in failed_results:
            logger.warning(f"  Clip {fail['index']}: {fail['error']}")

    if not successful_results:
        logger.error("No clips were processed successfully. Aborting concatenation.")
        return False

    # Sort results by index to maintain order
    successful_results.sort(key=lambda x: x["index"])
    clip_paths = [result["output_path"] for result in successful_results]

    # Concatenate all clips
    logger.info("Concatenating clips...")
    success = concatenate_clips(clip_paths, final_output_file)

    if success:
        logger.info(f"Final video created at: {final_output_file}")

    return success

# %%
from collections import namedtuple

# Define a Paragraph class or use a namedtuple

input_file = "/Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov"
output_dir = "/Users/andrew/Movies/Documentation/clips"
final_output = "/Users/andrew/Movies/Documentation/final_compilation.mov"

# Process all paragraphs and create the final video
process_paragraphs(filtered_list, input_file, output_dir, final_output)
# Out:
# 2025-03-05 15:18:31,119 - INFO - Processing clips in parallel with 4 workers
# 2025-03-05 15:18:31,120 - INFO - Processing clip 1: ffmpeg -ss 1.040 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 31.630 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_001.mov
# 2025-03-05 15:18:31,120 - INFO - Processing clip 2: ffmpeg -ss 33.770 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 14.376 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_002.mov
# 2025-03-05 15:18:31,120 - INFO - Processing clip 3: ffmpeg -ss 48.178 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 16.638 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_003.mov
# 2025-03-05 15:18:31,121 - INFO - Processing clip 4: ffmpeg -ss 220.644 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 17.646 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_004.mov
# 2025-03-05 15:18:48,783 - INFO - Successfully processed clip 2
# 2025-03-05 15:18:48,785 - INFO - Processing clip 5: ffmpeg -ss 277.160 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 31.900 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_005.mov
# 2025-03-05 15:18:52,328 - INFO - Successfully processed clip 3
# 2025-03-05 15:18:52,330 - INFO - Processing clip 6: ffmpeg -ss 921.790 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 41.940 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_006.mov
# 2025-03-05 15:18:53,395 - INFO - Successfully processed clip 4
# 2025-03-05 15:18:53,397 - INFO - Processing clip 7: ffmpeg -ss 1117.770 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 44.730 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_007.mov
# 2025-03-05 15:19:08,718 - INFO - Successfully processed clip 1
# 2025-03-05 15:19:08,720 - INFO - Processing clip 8: ffmpeg -ss 1190.980 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 56.312 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_008.mov
# 2025-03-05 15:19:26,101 - INFO - Successfully processed clip 5
# 2025-03-05 15:19:26,102 - INFO - Processing clip 9: ffmpeg -ss 1273.620 -i /Users/andrew/Movies/Documentation/2025-03-05 12-19-17.mov -to 10.820 -c:v libx264 -c:a aac -y /Users/andrew/Movies/Documentation/clips/clip_009.mov
# 2025-03-05 15:19:39,868 - INFO - Successfully processed clip 9
# 2025-03-05 15:19:44,020 - INFO - Successfully processed clip 6
# 2025-03-05 15:19:44,082 - INFO - Successfully processed clip 7
# 2025-03-05 15:19:53,059 - INFO - Successfully processed clip 8
# 2025-03-05 15:19:53,060 - INFO - Processed 9 clips successfully
# 2025-03-05 15:19:53,061 - INFO - Concatenating clips...
# 2025-03-05 15:19:53,063 - INFO - Created concat file at /var/folders/33/gmytc3cd4jv67wdgx63jm8dh0000gn/T/tmp62y1cq4v.txt
# 2025-03-05 15:19:53,063 - INFO - Running concat command: ffmpeg -f concat -safe 0 -i /var/folders/33/gmytc3cd4jv67wdgx63jm8dh0000gn/T/tmp62y1cq4v.txt -c copy -y /Users/andrew/Movies/Documentation/final_compilation.mov
# 2025-03-05 15:19:53,499 - INFO - Successfully concatenated clips to /Users/andrew/Movies/Documentation/final_compilation.mov
# 2025-03-05 15:19:53,500 - INFO - Final video created at: /Users/andrew/Movies/Documentation/final_compilation.mov
# True

# %%
from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip, ColorClip
import numpy as np


def instagram_caption_video(
    video_path,
    output_path,
    text,
    font_size=70,
    position="bottom",
    animation="fade",
    bg_opacity=0.7,
    duration_factor=0.8,  # Show caption for 80% of video duration
):
    """
    Create an Instagram-style captioned video

    Args:
        video_path: Path to input video
        output_path: Path for output video
        text: Text to display
        font_size: Size of the font
        position: Position ('top', 'center', 'bottom')
        animation: Animation style ('none', 'fade', 'typewriter', 'bounce')
        bg_opacity: Opacity of the background (0-1)
        duration_factor: How much of the video duration to show the caption
    """
    # Load the video
    video = VideoFileClip(video_path)

    # Calculate text duration
    text_duration = video.duration * duration_factor
    text_start = (video.duration - text_duration) / 2  # Center in time

    # Create text clip
    txt_clip = TextClip(
        text,
        fontsize=font_size,
        color="white",
        font="Arial-Bold",
        stroke_color="black",
        stroke_width=1,
    )

    # Size the background based on text size
    txt_width, txt_height = txt_clip.size
    bg_width = txt_width + 40  # Add padding
    bg_height = txt_height + 40

    # Create semi-transparent background
    bg_clip = ColorClip(size=(bg_width, bg_height), color=(0, 0, 0))
    bg_clip = bg_clip.set_opacity(bg_opacity)

    # Position the text on the background
    txt_clip = txt_clip.set_position("center")

    # Combine text and background
    txt_bg_clip = CompositeVideoClip([bg_clip, txt_clip])

    # Set position on the video
    if position == "top":
        txt_bg_clip = txt_bg_clip.set_position(("center", 50))
    elif position == "center":
        txt_bg_clip = txt_bg_clip.set_position("center")
    else:  # bottom
        txt_bg_clip = txt_bg_clip.set_position(("center", video.h - bg_height - 50))

    # Apply animation
    if animation == "fade":
        # Fade in and out
        def fade_func(t):
            # t is relative to the clip's start
            relative_t = (t - text_start) / text_duration if text_duration > 0 else 0
            if relative_t < 0 or relative_t > 1:
                return 0
            elif relative_t < 0.1:  # First 10% of time
                return relative_t / 0.1
            elif relative_t > 0.9:  # Last 10% of time
                return (1 - relative_t) / 0.1
            else:
                return 1

        txt_bg_clip = txt_bg_clip.set_opacity(fade_func)

    elif animation == "typewriter":
        # This would require a more complex implementation with multiple clips
        pass

    elif animation == "bounce":
        # Bouncing effect
        def bounce_pos(t):
            # t is relative to the clip's start
            relative_t = (t - text_start) / text_duration if text_duration > 0 else 0
            if position == "top":
                return ("center", 50 + np.sin(relative_t * 8) * 10)
            elif position == "center":
                return ("center", video.h / 2 + np.sin(relative_t * 8) * 10)
            else:  # bottom
                return (
                    "center",
                    video.h - bg_height - 50 + np.sin(relative_t * 8) * 10,
                )

        txt_bg_clip = txt_bg_clip.set_position(bounce_pos)

    # Set the timing
    txt_bg_clip = txt_bg_clip.set_start(text_start).set_duration(text_duration)

    # Composite with the video
    final_clip = CompositeVideoClip([video, txt_bg_clip])

    # Write the result
    final_clip.write_videofile(output_path, codec="libx264", audio_codec="aac")
